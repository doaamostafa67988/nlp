# %%
#
# NLP QUESTION
#
# Build and train a classifier for the sarcasm dataset.
# The classifier should have a final layer with 1 neuron activated by sigmoid as shown.
# It will be tested against a number of sentences that the network hasn't previously seen
# and you will be scored on whether sarcasm was correctly detected in those sentences.
import urllib

import numpy as np

import json
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
def solution_model():
    url = 'https://storage.googleapis.com/download.tensorflow.org/data/sarcasm.json'
    urllib.request.urlretrieve(url, 'sarcasm.json')

    # DO NOT CHANGE THIS CODE OR THE TESTS MAY NOT WORK
    vocab_size = 1000
    embedding_dim = 16
    max_length = 120
    trunc_type='post'
    padding_type='post'
    oov_tok = "<OOV>"
    training_size = 20000

    sentences = []
    labels = []
    urls =[]
    # YOUR CODE HERE
    with open("sarcasm.json", 'r') as f:
        datastore = json.load(f)

    for item in datastore:
        sentences.append(item['headline'])
        labels.append(item['is_sarcastic'])
        urls.append(item['article_link'])


    training_sentences = sentences[0:training_size]
    testing_sentences = sentences[training_size:]
    training_labels = labels[0:training_size]
    testing_labels = labels[training_size:]

    tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
    tokenizer.fit_on_texts(training_sentences)

    word_index = tokenizer.word_index

    training_sequences = tokenizer.texts_to_sequences(training_sentences)
    training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
    testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

    # Need this block to get it to work with TensorFlow 2.x

    training_padded = np.array(training_padded)
    training_labels = np.array(training_labels)
    testing_padded = np.array(testing_padded)
    testing_labels = np.array(testing_labels)

    model = tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
        tf.keras.layers.GlobalAveragePooling1D(),
        tf.keras.layers.Dense(24, activation='relu'),
    # YOUR CODE HERE. KEEP THIS OUTPUT LAYER INTACT OR TESTS MAY FAIL
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    num_epochs = 30
    history = model.fit(training_padded, training_labels, epochs=num_epochs,
                        validation_data=(testing_padded, testing_labels), verbose=2)
    return model


# Note that you'll need to save your model as a .h5 like this.
# When you press the Submit and Test button, your saved .h5 model will
# be sent to the testing infrastructure for scoring
# and the score will be returned to you.
if __name__ == '__main__':
    model = solution_model()
    model.save("mymodel.h5")
# Out:
# Epoch 1/30
# 625/625 - 8s - loss: 0.6818 - accuracy: 0.5595 - val_loss: 0.6658 - val_accuracy: 0.5633 - 8s/epoch - 12ms/step
# Epoch 2/30
# 625/625 - 3s - loss: 0.5558 - accuracy: 0.7177 - val_loss: 0.4751 - val_accuracy: 0.7804 - 3s/epoch - 5ms/step
# Epoch 3/30
# 625/625 - 3s - loss: 0.4223 - accuracy: 0.8109 - val_loss: 0.4199 - val_accuracy: 0.8073 - 3s/epoch - 5ms/step
# Epoch 4/30
# 625/625 - 3s - loss: 0.3905 - accuracy: 0.8212 - val_loss: 0.4077 - val_accuracy: 0.8155 - 3s/epoch - 5ms/step
# Epoch 5/30
# 625/625 - 3s - loss: 0.3766 - accuracy: 0.8288 - val_loss: 0.4060 - val_accuracy: 0.8103 - 3s/epoch - 5ms/step
# Epoch 6/30
# 625/625 - 3s - loss: 0.3698 - accuracy: 0.8311 - val_loss: 0.4010 - val_accuracy: 0.8156 - 3s/epoch - 5ms/step
# Epoch 7/30
# 625/625 - 3s - loss: 0.3625 - accuracy: 0.8344 - val_loss: 0.4006 - val_accuracy: 0.8170 - 3s/epoch - 5ms/step
# Epoch 8/30
# 625/625 - 3s - loss: 0.3592 - accuracy: 0.8372 - val_loss: 0.4010 - val_accuracy: 0.8162 - 3s/epoch - 5ms/step
# Epoch 9/30
# 625/625 - 3s - loss: 0.3572 - accuracy: 0.8378 - val_loss: 0.4115 - val_accuracy: 0.8070 - 3s/epoch - 5ms/step
# Epoch 10/30
# 625/625 - 3s - loss: 0.3557 - accuracy: 0.8371 - val_loss: 0.4058 - val_accuracy: 0.8098 - 3s/epoch - 5ms/step
# Epoch 11/30
# 625/625 - 3s - loss: 0.3532 - accuracy: 0.8406 - val_loss: 0.4019 - val_accuracy: 0.8141 - 3s/epoch - 5ms/step
# Epoch 12/30
# 625/625 - 3s - loss: 0.3520 - accuracy: 0.8408 - val_loss: 0.4101 - val_accuracy: 0.8064 - 3s/epoch - 5ms/step
# Epoch 13/30
# 625/625 - 3s - loss: 0.3510 - accuracy: 0.8407 - val_loss: 0.4045 - val_accuracy: 0.8120 - 3s/epoch - 5ms/step
# Epoch 14/30
# 625/625 - 3s - loss: 0.3501 - accuracy: 0.8404 - val_loss: 0.4043 - val_accuracy: 0.8135 - 3s/epoch - 5ms/step
# Epoch 15/30
# 625/625 - 3s - loss: 0.3491 - accuracy: 0.8403 - val_loss: 0.4160 - val_accuracy: 0.8034 - 3s/epoch - 5ms/step
# Epoch 16/30
# 625/625 - 3s - loss: 0.3494 - accuracy: 0.8407 - val_loss: 0.4094 - val_accuracy: 0.8103 - 3s/epoch - 5ms/step
# Epoch 17/30
# 625/625 - 3s - loss: 0.3482 - accuracy: 0.8429 - val_loss: 0.4074 - val_accuracy: 0.8135 - 3s/epoch - 5ms/step
# Epoch 18/30
# 625/625 - 3s - loss: 0.3479 - accuracy: 0.8435 - val_loss: 0.4230 - val_accuracy: 0.8034 - 3s/epoch - 5ms/step
# Epoch 19/30
# 625/625 - 3s - loss: 0.3483 - accuracy: 0.8415 - val_loss: 0.4196 - val_accuracy: 0.8117 - 3s/epoch - 5ms/step
# Epoch 20/30
# 625/625 - 3s - loss: 0.3483 - accuracy: 0.8415 - val_loss: 0.4139 - val_accuracy: 0.8110 - 3s/epoch - 5ms/step
# Epoch 21/30
# 625/625 - 3s - loss: 0.3478 - accuracy: 0.8410 - val_loss: 0.4083 - val_accuracy: 0.8131 - 3s/epoch - 5ms/step
# Epoch 22/30
# 625/625 - 3s - loss: 0.3473 - accuracy: 0.8419 - val_loss: 0.4072 - val_accuracy: 0.8138 - 3s/epoch - 5ms/step
# Epoch 23/30
# 625/625 - 3s - loss: 0.3464 - accuracy: 0.8443 - val_loss: 0.4078 - val_accuracy: 0.8123 - 3s/epoch - 5ms/step
# Epoch 24/30
# 625/625 - 3s - loss: 0.3468 - accuracy: 0.8414 - val_loss: 0.4106 - val_accuracy: 0.8103 - 3s/epoch - 5ms/step
# Epoch 25/30
# 625/625 - 3s - loss: 0.3473 - accuracy: 0.8440 - val_loss: 0.4128 - val_accuracy: 0.8110 - 3s/epoch - 5ms/step
# Epoch 26/30
# 625/625 - 3s - loss: 0.3467 - accuracy: 0.8418 - val_loss: 0.4124 - val_accuracy: 0.8111 - 3s/epoch - 5ms/step
# Epoch 27/30
# 625/625 - 3s - loss: 0.3465 - accuracy: 0.8435 - val_loss: 0.4091 - val_accuracy: 0.8134 - 3s/epoch - 5ms/step
# Epoch 28/30
# 625/625 - 3s - loss: 0.3466 - accuracy: 0.8419 - val_loss: 0.4172 - val_accuracy: 0.8055 - 3s/epoch - 5ms/step
# Epoch 29/30
# 625/625 - 3s - loss: 0.3463 - accuracy: 0.8424 - val_loss: 0.4094 - val_accuracy: 0.8134 - 3s/epoch - 5ms/step
# Epoch 30/30
# 625/625 - 3s - loss: 0.3451 - accuracy: 0.8446 - val_loss: 0.4095 - val_accuracy: 0.8113 - 3s/epoch - 5ms/step
